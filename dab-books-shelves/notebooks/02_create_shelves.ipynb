# %%
# %sql
CREATE OR REPLACE TABLE ${catalog_name}.${schema_name}.shelves (
  id INT PRIMARY KEY,
  location STRING,
  capacity INT,
  category STRING,
  floor_level INT,
  created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
);

# %%
# %sql
INSERT INTO ${catalog_name}.${schema_name}.shelves (id, location, capacity, category, floor_level)
VALUES 
  (1, 'Fiction Section A', 50, 'Fiction', 1),
  (2, 'Fiction Section B', 50, 'Fiction', 1),
  (3, 'Non-Fiction Section A', 40, 'Non-Fiction', 2),
  (4, 'Science Section', 30, 'Science', 2),
  (5, 'History Section', 35, 'History', 3),
  (6, 'Reference Section', 25, 'Reference', 3),
  (7, 'Children Section', 45, 'Children', 1),
  (8, 'Teen Section', 35, 'Teen', 2),
  (9, 'Rare Books Section', 15, 'Rare', 3),
  (10, 'Periodicals Section', 20, 'Periodicals', 1);

# %%
# %sql
SELECT * FROM ${catalog_name}.${schema_name}.shelves ORDER BY id;
