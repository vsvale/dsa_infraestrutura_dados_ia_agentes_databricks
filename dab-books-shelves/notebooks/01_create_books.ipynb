# %%
# %sql
CREATE OR REPLACE TABLE ${catalog_name}.${schema_name}.books (
  id INT PRIMARY KEY,
  title STRING,
  author STRING,
  isbn STRING,
  publication_year INT,
  shelf_id INT,
  created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
);

# %%
# %sql
INSERT INTO ${catalog_name}.${schema_name}.books (id, title, author, isbn, publication_year, shelf_id)
VALUES 
  (1, 'The Great Gatsby', 'F. Scott Fitzgerald', '978-0-7432-7356-5', 1925, 1),
  (2, 'To Kill a Mockingbird', 'Harper Lee', '978-0-06-112008-4', 1960, 1),
  (3, '1984', 'George Orwell', '978-0-452-28423-4', 1949, 2),
  (4, 'Pride and Prejudice', 'Jane Austen', '978-0-14-143951-8', 1813, 2),
  (5, 'The Catcher in the Rye', 'J.D. Salinger', '978-0-316-76948-0', 1951, 3),
  (6, 'Animal Farm', 'George Orwell', '978-0-452-28424-1', 1945, 3),
  (7, 'Brave New World', 'Aldous Huxley', '978-0-06-085052-4', 1932, 1),
  (8, 'The Hobbit', 'J.R.R. Tolkien', '978-0-547-92822-7', 1937, 2),
  (9, 'Fahrenheit 451', 'Ray Bradbury', '978-1-4516-7331-9', 1953, 3),
  (10, 'Jane Eyre', 'Charlotte Brontë', '978-0-14-144114-6', 1847, 1);

# %%
# %sql
SELECT * FROM ${catalog_name}.${schema_name}.books ORDER BY id;
